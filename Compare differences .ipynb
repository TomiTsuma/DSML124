# %%
import pandas as pd

# %%
df_pcc1 = pd.read_csv("outputFiles/PCC1_Classes_Reconstructed/exchangeable_acidity.csv")
df_pcc2 = pd.read_csv("outputFiles/PCC2_Classes_Reconstructed/exchangeable_acidity.csv")

# %%
df_pcc1.Difference.describe()
# Out:
# count    1332.000000
# mean        0.229768
# std         0.275470
# min         0.000138
# 25%         0.048277
# 50%         0.128268
# 75%         0.304130
# max         2.191986
# Name: Difference, dtype: float64

# %%
df_pcc2.Difference.describe()
# Out:
# count    131.000000
# mean       0.389354
# std        0.482368
# min        0.000034
# 25%        0.067257
# 50%        0.156559
# 75%        0.514782
# max        2.012747
# Name: Difference, dtype: float64

# %%
len(df_pcc2.loc[df_pcc2['Difference'] > 0.3893548]) / len (df_pcc2)
# Out:
# 0.32061068702290074

# %%
len(df_pcc1.loc[df_pcc1['Difference'] < 2.012747]) / len (df_pcc1)
# Out:
# 0.9992492492492493
